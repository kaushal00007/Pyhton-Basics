# %%
import pandas as pd
import numpy as np
df = pd.read_csv("C:\Pyhton-course\sample.csv", sep=',', header = 0)

# %%
df.head()
# Out:
#    id first_name   last_name  gender           City  \
# 0   1    Melinde   Shilburne  Female      Nowa Ruda
# 1   2   Kimberly  Von Welden  Female         Bulgan
# 2   3     Alvera    Di Boldi  Female            NaN
# 3   4    Shannon   O'Griffin    Male  Divnomorskoye
# 4   5   Sherwood     Macieja    Male      Mytishchi
#
#                       Job Title     Salary   Latitude   Longitude
# 0           Assistant Professor  $57438.18  50.577407   16.496718
# 1                 Programmer II  $62846.60  48.823157  103.521820
# 2                           NaN  $57576.52  39.994746  116.339773
# 3  Budget/Accounting Analyst II  $61489.23  44.504721   38.130017
# 4                      VP Sales  $63863.09        NaN   37.648995

# %%
df.groupby('gender')['Salary'].mean()
# Out:
# ---------------------------------------------------------------------------
# DataError                                 Traceback (most recent call last)
# <ipython-input-7-b6d0883028be> in <module>
# ----> 1 df.groupby('gender')['Salary'].mean()
#
# c:\program files\python37\lib\site-packages\pandas\core\groupby\groupby.py in mean(self, numeric_only)
#    1396             "mean",
#    1397             alt=lambda x, axis: Series(x).mean(numeric_only=numeric_only),
# -> 1398             numeric_only=numeric_only,
#    1399         )
#    1400
#
# c:\program files\python37\lib\site-packages\pandas\core\groupby\groupby.py in _cython_agg_general(self, how, alt, numeric_only, min_count)
#    1051
#    1052         if len(output) == 0:
# -> 1053             raise DataError("No numeric types to aggregate")
#    1054
#    1055         return self._wrap_aggregated_output(output, index=self.grouper.result_index)
#
# DataError: No numeric types to aggregate

# %%
df['Salary'].dtype
# Out:
# dtype('O')

# %%
def clean_salary(row):
    salary = row['Salary'].replace('$','')
    salary = float(salary)
    return salary

df['clean_salary'] = df.apply(clean_salary,axis = 1)

# %%
df.head()
# Out:
#    id first_name   last_name  gender           City  \
# 0   1    Melinde   Shilburne  Female      Nowa Ruda
# 1   2   Kimberly  Von Welden  Female         Bulgan
# 2   3     Alvera    Di Boldi  Female            NaN
# 3   4    Shannon   O'Griffin    Male  Divnomorskoye
# 4   5   Sherwood     Macieja    Male      Mytishchi
#
#                       Job Title     Salary   Latitude   Longitude  \
# 0           Assistant Professor  $57438.18  50.577407   16.496718
# 1                 Programmer II  $62846.60  48.823157  103.521820
# 2                           NaN  $57576.52  39.994746  116.339773
# 3  Budget/Accounting Analyst II  $61489.23  44.504721   38.130017
# 4                      VP Sales  $63863.09        NaN   37.648995
#
#    clean_salary
# 0      57438.18
# 1      62846.60
# 2      57576.52
# 3      61489.23
# 4      63863.09

# %%
df.groupby('gender')['clean_salary'].mean()
# Out:
# gender
# Female    55618.943049
# Male      55361.093839
# Name: clean_salary, dtype: float64

# %%
df.groupby('City')['clean_salary'].sum()
# Out:
# City
# Abéché                 93375.18
# Ad Dimnah              70973.35
# Adigeni                58517.11
# Agios Dimitrios        32930.55
# Aguaí                  56279.89
#                          ...
# Šluknov                49332.48
# Šmartno pri Litiji     35287.31
# Žrnovo                 74782.64
# Ḩajjah                 52017.77
# ‘Aşīrah al Qiblīyah    42951.88
# Name: clean_salary, Length: 968, dtype: float64

# %%
df.groupby(['City','gender'])['clean_salary'].mean()
# Out:
# City                 gender
# Abéché               Female    93375.18
# Ad Dimnah            Male      70973.35
# Adigeni              Female    58517.11
# Agios Dimitrios      Female    32930.55
# Aguaí                Male      56279.89
#                                  ...
# Šluknov              Female    49332.48
# Šmartno pri Litiji   Male      35287.31
# Žrnovo               Male      74782.64
# Ḩajjah               Male      52017.77
# ‘Aşīrah al Qiblīyah  Male      42951.88
# Name: clean_salary, Length: 982, dtype: float64

# %%
def female_salary(row):
    if row['gender'] == 'Female':
        return row['clean_salary']
df['female_salary'] = df.apply(female_salary,axis=1 )
df.head()
# Out:
#    id first_name   last_name  gender           City  \
# 0   1    Melinde   Shilburne  Female      Nowa Ruda
# 1   2   Kimberly  Von Welden  Female         Bulgan
# 2   3     Alvera    Di Boldi  Female            NaN
# 3   4    Shannon   O'Griffin    Male  Divnomorskoye
# 4   5   Sherwood     Macieja    Male      Mytishchi
#
#                       Job Title     Salary   Latitude   Longitude  \
# 0           Assistant Professor  $57438.18  50.577407   16.496718
# 1                 Programmer II  $62846.60  48.823157  103.521820
# 2                           NaN  $57576.52  39.994746  116.339773
# 3  Budget/Accounting Analyst II  $61489.23  44.504721   38.130017
# 4                      VP Sales  $63863.09        NaN   37.648995
#
#    clean_salary  female_salary
# 0      57438.18       57438.18
# 1      62846.60       62846.60
# 2      57576.52       57576.52
# 3      61489.23            NaN
# 4      63863.09            NaN

# %%
def male_salary(row):
    if row['gender'] == 'Male':
        return row['clean_salary']
df['male_salary'] = df.apply(male_salary,axis=1)
df.head()
#df.columns
# Out:
#    id first_name   last_name  gender           City  \
# 0   1    Melinde   Shilburne  Female      Nowa Ruda
# 1   2   Kimberly  Von Welden  Female         Bulgan
# 2   3     Alvera    Di Boldi  Female            NaN
# 3   4    Shannon   O'Griffin    Male  Divnomorskoye
# 4   5   Sherwood     Macieja    Male      Mytishchi
#
#                       Job Title     Salary   Latitude   Longitude  \
# 0           Assistant Professor  $57438.18  50.577407   16.496718
# 1                 Programmer II  $62846.60  48.823157  103.521820
# 2                           NaN  $57576.52  39.994746  116.339773
# 3  Budget/Accounting Analyst II  $61489.23  44.504721   38.130017
# 4                      VP Sales  $63863.09        NaN   37.648995
#
#    clean_salary  female_salary  male_salary
# 0      57438.18       57438.18          NaN
# 1      62846.60       62846.60          NaN
# 2      57576.52       57576.52          NaN
# 3      61489.23            NaN     61489.23
# ...

# %%
df.groupby(['Job Title','City'])['clean_salary','male_salary','female_salary'].mean()
# Out:
# c:\program files\python37\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   """Entry point for launching an IPython kernel.
#                                  clean_salary  male_salary  female_salary
# Job Title           City
# Account Coordinator Beishidian       21091.80          NaN       21091.80
#                     Gengwan          67073.36          NaN       67073.36
#                     Lluchubamba      84527.06     84527.06            NaN
#                     Nusajaya         71637.92          NaN       71637.92
#                     Rajapeni         27026.70          NaN       27026.70
# ...                                       ...          ...            ...
# Web Developer I     Xin’e            62755.85     62755.85            NaN
# Web Developer II    Cacheu           13772.82          NaN       13772.82
# ...

# %%
import pandas as pd
import numpy as np
df = pd.read_csv("C:\Pyhton-course\exercise_course.csv", sep=',', header = 0)
df.head()
# Out:
#                            username  gender request time  \
# 0            sgather0@princeton.edu  Female      6:24 AM
# 1               mmyton1@twitter.com  Female     10:01 PM
# 2  cbischof2@scientificamerican.com  Female     10:58 PM
# 3            rfowkes3@pinterest.com    Male      1:51 PM
# 4               cancliffe4@usgs.gov    Male      4:21 AM
#
#                  country                          url  bytes
# 0                  China           http://tinyurl.com    168
# 1                 Brazil       http://miibeian.gov.cn    858
# 2                 France           http://dedecms.com    945
# 3                  China                http://va.gov    836
# 4  Palestinian Territory  https://theglobeandmail.com    719

# %%
def female_bytes(row):
    if row['gender'] == 'Female':
        return row['bytes']
df['female_bytes'] = df.apply(female_bytes,axis=1)

#    sum_bytes_per_domain = row['url']['bytes'].sum()
#df = df.groupby('url')['bytes'].sum().reset_index()
#df2 = df.sort_values('bytes',ascending = False)
#df2.head()
#df = df.groupby('url')['male_bytes','female_bytes']
#df2 = df.sort_values('bytes', ascending=False)
#df2d
df
# Out:
#                               username  gender request time  \
# 0               sgather0@princeton.edu  Female      6:24 AM
# 1                  mmyton1@twitter.com  Female     10:01 PM
# 2     cbischof2@scientificamerican.com  Female     10:58 PM
# 3               rfowkes3@pinterest.com    Male      1:51 PM
# 4                  cancliffe4@usgs.gov    Male      4:21 AM
# ..                                 ...     ...          ...
# 995              rminghettirn@youtu.be    Male      5:58 AM
# 996                  mjakoro@prweb.com  Female     11:04 PM
# 997  jruprichrp@networkadvertising.org    Male     12:09 AM
# 998            jdehmelrq@123-reg.co.uk    Male      6:56 PM
# 999           cgillimghamrr@unesco.org    Male      4:28 AM
#
#                    country                          url  bytes  female_bytes
# 0                    China           http://tinyurl.com    168         168.0
# 1                   Brazil       http://miibeian.gov.cn    858         858.0
# ...

# %%
def male_bytes(row):
    if row['gender'] == 'Male':
        return row['bytes']
df['male_bytes'] = df.apply(male_bytes,axis=1)

# %%
df.head()
# Out:
#                            username  gender request time  \
# 0            sgather0@princeton.edu  Female      6:24 AM
# 1               mmyton1@twitter.com  Female     10:01 PM
# 2  cbischof2@scientificamerican.com  Female     10:58 PM
# 3            rfowkes3@pinterest.com    Male      1:51 PM
# 4               cancliffe4@usgs.gov    Male      4:21 AM
#
#                  country                          url  bytes  female_bytes  \
# 0                  China           http://tinyurl.com    168         168.0
# 1                 Brazil       http://miibeian.gov.cn    858         858.0
# 2                 France           http://dedecms.com    945         945.0
# 3                  China                http://va.gov    836           NaN
# 4  Palestinian Territory  https://theglobeandmail.com    719           NaN
#
#    male_bytes
# 0         NaN
# 1         NaN
# 2         NaN
# 3       836.0
# 4       719.0

# %%
df2 = df.groupby(['country','url'])['male_bytes','female_bytes'].sum()
df2
# Out:
# c:\program files\python37\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   """Entry point for launching an IPython kernel.
#                                             male_bytes  female_bytes
# country     url
# Afghanistan http://oaic.gov.au                     0.0         895.0
#             http://paginegialle.it                 0.0         145.0
#             https://wufoo.com                      0.0         579.0
# Albania     http://nature.com                      0.0         927.0
#             http://wisc.edu                        0.0         328.0
# ...                                                ...           ...
# Yemen       http://nhs.uk                        395.0           0.0
#             https://nationalgeographic.com         0.0         505.0
# Zambia      http://yolasite.com                    0.0         417.0
# ...

# %%
import pandas

# %%
print ("HI")
# Out:
# HI

# %%
import re
hand = open("C:\\Pyhton-course\\mbox-short.txt")
for line in hand:
    if re.search('^From:',line):
        print (line)
# Out:
# From: stephen.marquard@uct.ac.za
#
# From: louis@media.berkeley.edu
#
# From: zqian@umich.edu
#
# From: rjlowe@iupui.edu
#
# From: zqian@umich.edu
#
# From: rjlowe@iupui.edu
#
# From: cwen@iupui.edu
#
# From: cwen@iupui.edu
#
# From: gsilver@umich.edu
#
# From: gsilver@umich.edu
#
# From: zqian@umich.edu
#
# From: gsilver@umich.edu
#
# From: wagnermr@iupui.edu
#
# From: zqian@umich.edu
#
# From: antranig@caret.cam.ac.uk
#
# From: gopal.ramasammycook@gmail.com
#
# From: david.horwitz@uct.ac.za
#
# From: david.horwitz@uct.ac.za
#
# From: david.horwitz@uct.ac.za
#
# From: david.horwitz@uct.ac.za
#
# From: stephen.marquard@uct.ac.za
#
# From: louis@media.berkeley.edu
#
# From: louis@media.berkeley.edu
#
# From: ray@media.berkeley.edu
#
# From: cwen@iupui.edu
#
# From: cwen@iupui.edu
#
# From: cwen@iupui.edu

# %%
import re
hand = open("C:\\Pyhton-course\\mbox-short.txt")
for line in hand:
    if re.search('^F..m:',line):
        print (line)
# Out:
# From: stephen.marquard@uct.ac.za
#
# From: louis@media.berkeley.edu
#
# From: zqian@umich.edu
#
# From: rjlowe@iupui.edu
#
# From: zqian@umich.edu
#
# From: rjlowe@iupui.edu
#
# From: cwen@iupui.edu
#
# From: cwen@iupui.edu
#
# From: gsilver@umich.edu
#
# From: gsilver@umich.edu
#
# From: zqian@umich.edu
#
# From: gsilver@umich.edu
#
# From: wagnermr@iupui.edu
#
# From: zqian@umich.edu
#
# From: antranig@caret.cam.ac.uk
#
# From: gopal.ramasammycook@gmail.com
#
# From: david.horwitz@uct.ac.za
#
# From: david.horwitz@uct.ac.za
#
# From: david.horwitz@uct.ac.za
#
# From: david.horwitz@uct.ac.za
#
# From: stephen.marquard@uct.ac.za
#
# From: louis@media.berkeley.edu
#
# From: louis@media.berkeley.edu
#
# From: ray@media.berkeley.edu
#
# From: cwen@iupui.edu
#
# From: cwen@iupui.edu
#
# From: cwen@iupui.edu

# %%
import re
s = 'A message from csev@umich.edu to cwen@iupui.edu about meeting @2PM'
lst = re.findall('\S+@\S+', s)
print(lst)
# Out:
# ['csev@umich.edu', 'cwen@iupui.edu']

# %%
import re
hand = open("C:\\Pyhton-course\\mbox-short.txt")
for line in hand:
    line = line.rstrip()
    x= re.findall('^F..m:*@\S*[a-zA-Z0-9]',line)
    if len(x)>0:
        print (line)

# %%
import re
hand = open("C:\\Pyhton-course\\mbox-short.txt")
for line in hand:
    line = line.rstrip()
    x= re.findall('^X-.*: [0-9.]+',line)
    if len(x)>0:
        print (line)
# Out:
# X-DSPAM-Confidence: 0.8475
# X-DSPAM-Probability: 0.0000
# X-DSPAM-Confidence: 0.6178
# X-DSPAM-Probability: 0.0000
# X-DSPAM-Confidence: 0.6961
# X-DSPAM-Probability: 0.0000
# X-DSPAM-Confidence: 0.7565
# X-DSPAM-Probability: 0.0000
# X-DSPAM-Confidence: 0.7626
# X-DSPAM-Probability: 0.0000
# X-DSPAM-Confidence: 0.7556
# X-DSPAM-Probability: 0.0000
# X-DSPAM-Confidence: 0.7002
# X-DSPAM-Probability: 0.0000
# X-DSPAM-Confidence: 0.7615
# X-DSPAM-Probability: 0.0000
# X-DSPAM-Confidence: 0.7601
# X-DSPAM-Probability: 0.0000
# X-DSPAM-Confidence: 0.7605
# X-DSPAM-Probability: 0.0000
# X-DSPAM-Confidence: 0.6959
# X-DSPAM-Probability: 0.0000
# X-DSPAM-Confidence: 0.7606
# X-DSPAM-Probability: 0.0000
# X-DSPAM-Confidence: 0.7559
# X-DSPAM-Probability: 0.0000
# X-DSPAM-Confidence: 0.7605
# X-DSPAM-Probability: 0.0000
# X-DSPAM-Confidence: 0.6932
# X-DSPAM-Probability: 0.0000
# X-DSPAM-Confidence: 0.7558
# X-DSPAM-Probability: 0.0000
# X-DSPAM-Confidence: 0.6526
# ...

# %%
import re
hand = open("C:\\Pyhton-course\\mbox-short.txt")
for line in hand:
    line = line.rstrip()
    x = re.findall('^X\S*: ([0-9.]+)', line)
    if len(x)>0:
        print (line)
# Out:
# X-DSPAM-Confidence: 0.8475
# X-DSPAM-Probability: 0.0000
# X-DSPAM-Confidence: 0.6178
# X-DSPAM-Probability: 0.0000
# X-DSPAM-Confidence: 0.6961
# X-DSPAM-Probability: 0.0000
# X-DSPAM-Confidence: 0.7565
# X-DSPAM-Probability: 0.0000
# X-DSPAM-Confidence: 0.7626
# X-DSPAM-Probability: 0.0000
# X-DSPAM-Confidence: 0.7556
# X-DSPAM-Probability: 0.0000
# X-DSPAM-Confidence: 0.7002
# X-DSPAM-Probability: 0.0000
# X-DSPAM-Confidence: 0.7615
# X-DSPAM-Probability: 0.0000
# X-DSPAM-Confidence: 0.7601
# X-DSPAM-Probability: 0.0000
# X-DSPAM-Confidence: 0.7605
# X-DSPAM-Probability: 0.0000
# X-DSPAM-Confidence: 0.6959
# X-DSPAM-Probability: 0.0000
# X-DSPAM-Confidence: 0.7606
# X-DSPAM-Probability: 0.0000
# X-DSPAM-Confidence: 0.7559
# X-DSPAM-Probability: 0.0000
# X-DSPAM-Confidence: 0.7605
# X-DSPAM-Probability: 0.0000
# X-DSPAM-Confidence: 0.6932
# X-DSPAM-Probability: 0.0000
# X-DSPAM-Confidence: 0.7558
# X-DSPAM-Probability: 0.0000
# X-DSPAM-Confidence: 0.6526
# ...

# %%
import re
hand = open("C:\\Pyhton-course\\mbox-short.txt")
for line in hand:
    line = line.rstrip()
    x = re.findall('^X\S*: ([0-9.]+)', line)
    if len(x) > 0:
       print(x)
# Out:
# ['0.8475']
# ['0.0000']
# ['0.6178']
# ['0.0000']
# ['0.6961']
# ['0.0000']
# ['0.7565']
# ['0.0000']
# ['0.7626']
# ['0.0000']
# ['0.7556']
# ['0.0000']
# ['0.7002']
# ['0.0000']
# ['0.7615']
# ['0.0000']
# ['0.7601']
# ['0.0000']
# ['0.7605']
# ['0.0000']
# ['0.6959']
# ['0.0000']
# ['0.7606']
# ['0.0000']
# ['0.7559']
# ['0.0000']
# ['0.7605']
# ['0.0000']
# ['0.6932']
# ['0.0000']
# ['0.7558']
# ['0.0000']
# ['0.6526']
# ['0.0000']
# ['0.6948']
# ['0.0000']
# ['0.6528']
# ['0.0000']
# ['0.7002']
# ['0.0000']
# ['0.7554']
# ['0.0000']
# ['0.6956']
# ['0.0000']
# ['0.6959']
# ['0.0000']
# ['0.7556']
# ['0.0000']
# ['0.9846']
# ['0.0000']
# ['0.8509']
# ['0.0000']
# ['0.9907']
# ['0.0000']

# %%
import pandas as pd
df = pd.read_csv("C:\\Pyhton-course\\sample.csv", sep=',', header = 0)
df.head()
# Out:
#    id first_name   last_name  gender           City  \
# 0   1    Melinde   Shilburne  Female      Nowa Ruda
# 1   2   Kimberly  Von Welden  Female         Bulgan
# 2   3     Alvera    Di Boldi  Female            NaN
# 3   4    Shannon   O'Griffin    Male  Divnomorskoye
# 4   5   Sherwood     Macieja    Male      Mytishchi
#
#                       Job Title     Salary   Latitude   Longitude
# 0           Assistant Professor  $57438.18  50.577407   16.496718
# 1                 Programmer II  $62846.60  48.823157  103.521820
# 2                           NaN  $57576.52  39.994746  116.339773
# 3  Budget/Accounting Analyst II  $61489.23  44.504721   38.130017
# 4                      VP Sales  $63863.09        NaN   37.648995

# %%
df.groupby('gender')['Salary'].mean()
# Out:
# ---------------------------------------------------------------------------
# DataError                                 Traceback (most recent call last)
# <ipython-input-6-b6d0883028be> in <module>
# ----> 1 df.groupby('gender')['Salary'].mean()
#
# c:\program files\python37\lib\site-packages\pandas\core\groupby\groupby.py in mean(self, numeric_only)
#    1396             "mean",
#    1397             alt=lambda x, axis: Series(x).mean(numeric_only=numeric_only),
# -> 1398             numeric_only=numeric_only,
#    1399         )
#    1400
#
# c:\program files\python37\lib\site-packages\pandas\core\groupby\groupby.py in _cython_agg_general(self, how, alt, numeric_only, min_count)
#    1051
#    1052         if len(output) == 0:
# -> 1053             raise DataError("No numeric types to aggregate")
#    1054
#    1055         return self._wrap_aggregated_output(output, index=self.grouper.result_index)
#
# DataError: No numeric types to aggregate

# %%
def cleanup_salary( row ):
    clean_salary = row['Salary'].replace('$','')
    clean_salary = float(clean_salary)
    return clean_salary

df['clean_salary'] = df.apply(cleanup_salary, axis = 1)
df.head()
# Out:
#    id first_name   last_name  gender           City  \
# 0   1    Melinde   Shilburne  Female      Nowa Ruda
# 1   2   Kimberly  Von Welden  Female         Bulgan
# 2   3     Alvera    Di Boldi  Female            NaN
# 3   4    Shannon   O'Griffin    Male  Divnomorskoye
# 4   5   Sherwood     Macieja    Male      Mytishchi
#
#                       Job Title     Salary   Latitude   Longitude  \
# 0           Assistant Professor  $57438.18  50.577407   16.496718
# 1                 Programmer II  $62846.60  48.823157  103.521820
# 2                           NaN  $57576.52  39.994746  116.339773
# 3  Budget/Accounting Analyst II  $61489.23  44.504721   38.130017
# 4                      VP Sales  $63863.09        NaN   37.648995
#
#    clean_salary
# 0      57438.18
# 1      62846.60
# 2      57576.52
# 3      61489.23
# 4      63863.09

# %%
df.groupby('gender')['clean_salary'].mean()
# Out:
# gender
# Female    55618.943049
# Male      55361.093839
# Name: clean_salary, dtype: float64

# %%
def female_salary(row):
    if row['gender'] == 'Female':
        return row['clean_salary']
df['female_salary'] = df.apply(female_salary, axis = 1)
df.head()
# Out:
#    id first_name   last_name  gender           City  \
# 0   1    Melinde   Shilburne  Female      Nowa Ruda
# 1   2   Kimberly  Von Welden  Female         Bulgan
# 2   3     Alvera    Di Boldi  Female            NaN
# 3   4    Shannon   O'Griffin    Male  Divnomorskoye
# 4   5   Sherwood     Macieja    Male      Mytishchi
#
#                       Job Title     Salary   Latitude   Longitude  \
# 0           Assistant Professor  $57438.18  50.577407   16.496718
# 1                 Programmer II  $62846.60  48.823157  103.521820
# 2                           NaN  $57576.52  39.994746  116.339773
# 3  Budget/Accounting Analyst II  $61489.23  44.504721   38.130017
# 4                      VP Sales  $63863.09        NaN   37.648995
#
#    clean_salary  female_salary
# 0      57438.18       57438.18
# 1      62846.60       62846.60
# 2      57576.52       57576.52
# 3      61489.23            NaN
# 4      63863.09            NaN

# %%
def male_salary(row):
    if row['gender'] == 'Male':
        return row['clean_salary']
df['male_salary'] = df.apply(male_salary, axis = 1)
df.head()
# Out:
#    id first_name   last_name  gender           City  \
# 0   1    Melinde   Shilburne  Female      Nowa Ruda
# 1   2   Kimberly  Von Welden  Female         Bulgan
# 2   3     Alvera    Di Boldi  Female            NaN
# 3   4    Shannon   O'Griffin    Male  Divnomorskoye
# 4   5   Sherwood     Macieja    Male      Mytishchi
#
#                       Job Title     Salary   Latitude   Longitude  \
# 0           Assistant Professor  $57438.18  50.577407   16.496718
# 1                 Programmer II  $62846.60  48.823157  103.521820
# 2                           NaN  $57576.52  39.994746  116.339773
# 3  Budget/Accounting Analyst II  $61489.23  44.504721   38.130017
# 4                      VP Sales  $63863.09        NaN   37.648995
#
#    clean_salary  female_salary  male_salary
# 0      57438.18       57438.18          NaN
# 1      62846.60       62846.60          NaN
# 2      57576.52       57576.52          NaN
# 3      61489.23            NaN     61489.23
# ...

# %%
df.groupby('Job Title')['clean_salary','female_salary','male_salary'].mean()
# Out:
# c:\program files\python37\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   """Entry point for launching an IPython kernel.
#                             clean_salary  female_salary   male_salary
# Job Title
# Account Coordinator         48738.521429   46707.445000  51446.623333
# Account Executive           58718.374000   52020.780000  65415.968000
# Account Representative I    51116.973333   51116.973333           NaN
# Account Representative II   41174.805000   41786.910000  40562.700000
# Account Representative III  22420.710000            NaN  22420.710000
# ...                                  ...            ...           ...
# Web Designer II             85660.120000   92636.000000  64732.480000
# Web Designer IV             42073.720000   21108.230000  63039.210000
# Web Developer I             79405.830000            NaN  79405.830000
# ...

# %%
df.groupby(['Job Title','City'])['clean_salary','female_salary','male_salary'].mean()
# Out:
# c:\program files\python37\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   """Entry point for launching an IPython kernel.
#                                  clean_salary  female_salary  male_salary
# Job Title           City
# Account Coordinator Beishidian       21091.80       21091.80          NaN
#                     Gengwan          67073.36       67073.36          NaN
#                     Lluchubamba      84527.06            NaN     84527.06
#                     Nusajaya         71637.92       71637.92          NaN
#                     Rajapeni         27026.70       27026.70          NaN
# ...                                       ...            ...          ...
# Web Developer I     Xin’e            62755.85            NaN     62755.85
# Web Developer II    Cacheu           13772.82       13772.82          NaN
# ...

# %%
df.columns
# Out:
# Index(['id', 'first_name', 'last_name', 'gender', 'City', 'Job Title',
#        'Salary', 'Latitude', 'Longitude', 'clean_salary', 'female_salary',
#        'male_salary'],
#       dtype='object')

# %%
df.describe
# Out:
# <bound method NDFrame.describe of        id  first_name   last_name  gender           City  \
# 0       1     Melinde   Shilburne  Female      Nowa Ruda
# 1       2    Kimberly  Von Welden  Female         Bulgan
# 2       3      Alvera    Di Boldi  Female            NaN
# 3       4     Shannon   O'Griffin    Male  Divnomorskoye
# 4       5    Sherwood     Macieja    Male      Mytishchi
# ..    ...         ...         ...     ...            ...
# 995   996      Kathye     Grasser  Female       Dzaoudzi
# 996   997     Haskell    Kempston    Male  Ban Talat Nua
# 997   998  Holly-anne       Gerbl  Female        Guanaja
# 998   999      Marysa      Purdie  Female          Sioah
# 999  1000      Jewell    Haselden  Female    Springfield
#
#                                 Job Title     Salary   Latitude   Longitude  \
# 0                     Assistant Professor  $57438.18  50.577407   16.496718
# 1                           Programmer II  $62846.60  48.823157  103.521820
# ...

# %%
df.shape
# Out:
# (1000, 12)

# %%
df.info
# Out:
# <bound method DataFrame.info of        id  first_name   last_name  gender           City  \
# 0       1     Melinde   Shilburne  Female      Nowa Ruda
# 1       2    Kimberly  Von Welden  Female         Bulgan
# 2       3      Alvera    Di Boldi  Female            NaN
# 3       4     Shannon   O'Griffin    Male  Divnomorskoye
# 4       5    Sherwood     Macieja    Male      Mytishchi
# ..    ...         ...         ...     ...            ...
# 995   996      Kathye     Grasser  Female       Dzaoudzi
# 996   997     Haskell    Kempston    Male  Ban Talat Nua
# 997   998  Holly-anne       Gerbl  Female        Guanaja
# 998   999      Marysa      Purdie  Female          Sioah
# 999  1000      Jewell    Haselden  Female    Springfield
#
#                                 Job Title     Salary   Latitude   Longitude  \
# 0                     Assistant Professor  $57438.18  50.577407   16.496718
# 1                           Programmer II  $62846.60  48.823157  103.521820
# ...

# %%
mean_female_salary = df['female_salary'].mean()
#print (mean_female_salary )
df['female_salary'].fillna(mean_female_salary, inplace=True)
mean_male_salary = df['male_salary'].mean()
df['male_salary'].fillna(mean_male_salary, inplace=True)
df.head()
# Out:
#    id first_name   last_name  gender           City  \
# 0   1    Melinde   Shilburne  Female      Nowa Ruda
# 1   2   Kimberly  Von Welden  Female         Bulgan
# 2   3     Alvera    Di Boldi  Female            NaN
# 3   4    Shannon   O'Griffin    Male  Divnomorskoye
# 4   5   Sherwood     Macieja    Male      Mytishchi
#
#                       Job Title     Salary   Latitude   Longitude  \
# 0           Assistant Professor  $57438.18  50.577407   16.496718
# 1                 Programmer II  $62846.60  48.823157  103.521820
# 2                           NaN  $57576.52  39.994746  116.339773
# 3  Budget/Accounting Analyst II  $61489.23  44.504721   38.130017
# 4                      VP Sales  $63863.09        NaN   37.648995
#
#    clean_salary  female_salary   male_salary
# 0      57438.18   57438.180000  55361.093839
# 1      62846.60   62846.600000  55361.093839
# 2      57576.52   57576.520000  55361.093839
# 3      61489.23   55618.943049  61489.230000
# ...

# %%
df['City'].fillna('London', inplace = True)

# %%
df.head()
# Out:
#    id first_name   last_name  gender           City  \
# 0   1    Melinde   Shilburne  Female      Nowa Ruda
# 1   2   Kimberly  Von Welden  Female         Bulgan
# 2   3     Alvera    Di Boldi  Female         London
# 3   4    Shannon   O'Griffin    Male  Divnomorskoye
# 4   5   Sherwood     Macieja    Male      Mytishchi
#
#                       Job Title     Salary   Latitude   Longitude  \
# 0           Assistant Professor  $57438.18  50.577407   16.496718
# 1                 Programmer II  $62846.60  48.823157  103.521820
# 2                           NaN  $57576.52  39.994746  116.339773
# 3  Budget/Accounting Analyst II  $61489.23  44.504721   38.130017
# 4                      VP Sales  $63863.09        NaN   37.648995
#
#    clean_salary  female_salary   male_salary
# 0      57438.18   57438.180000  55361.093839
# 1      62846.60   62846.600000  55361.093839
# 2      57576.52   57576.520000  55361.093839
# 3      61489.23   55618.943049  61489.230000
# ...

# %%
df2 = df.dropna()
df2.head()
# Out:
#    id first_name   last_name  gender             City  \
# 0   1    Melinde   Shilburne  Female        Nowa Ruda
# 1   2   Kimberly  Von Welden  Female           Bulgan
# 3   4    Shannon   O'Griffin    Male    Divnomorskoye
# 5   6      Maris        Folk  Female  Kinsealy-Drinan
# 7   8    Goddart       Flear    Male        Trélissac
#
#                       Job Title     Salary   Latitude   Longitude  \
# 0           Assistant Professor  $57438.18  50.577407   16.496718
# 1                 Programmer II  $62846.60  48.823157  103.521820
# 3  Budget/Accounting Analyst II  $61489.23  44.504721   38.130017
# 5                Civil Engineer  $30101.16  53.426614   -6.164500
# 7    Desktop Support Technician  $46116.36  45.190519    0.742312
#
#    clean_salary  female_salary   male_salary
# 0      57438.18   57438.180000  55361.093839
# 1      62846.60   62846.600000  55361.093839
# 3      61489.23   55618.943049  61489.230000
# 5      30101.16   30101.160000  55361.093839
# ...

# %%
df.shape
# Out:
# (1000, 12)

# %%
df3 = df.drop_duplicates()
df3.shape
# Out:
# (1000, 12)

# %%
df4 = df['first_name'].drop_duplicates()
df4.shape
# Out:
# (942,)

# %%
df5 = df.drop_duplicates(['first_name'], keep='last')
df5.shape
# Out:
# (942, 12)

# %%
df.loc[df['clean_salary'] > 50000]
# Out:
#       id first_name   last_name  gender             City  \
# 0      1    Melinde   Shilburne  Female        Nowa Ruda
# 1      2   Kimberly  Von Welden  Female           Bulgan
# 2      3     Alvera    Di Boldi  Female           London
# 3      4    Shannon   O'Griffin    Male    Divnomorskoye
# 4      5   Sherwood     Macieja    Male        Mytishchi
# ..   ...        ...         ...     ...              ...
# 991  992     Scotti       Dusey    Male     Medveditskiy
# 992  993       Levi     Ramsell    Male      Lluchubamba
# 994  995       Niki    Ashbrook    Male  Novozavidovskiy
# 995  996     Kathye     Grasser  Female         Dzaoudzi
# 998  999     Marysa      Purdie  Female            Sioah
#
#                         Job Title     Salary   Latitude   Longitude  \
# 0             Assistant Professor  $57438.18  50.577407   16.496718
# 1                   Programmer II  $62846.60  48.823157  103.521820
# 2                             NaN  $57576.52  39.994746  116.339773
# ...

# %%
df.loc[( df['clean_salary'] > 70000) & ( df['clean_salary'] < 90000)]
# Out:
#       id  first_name    last_name  gender          City  \
# 8      9        Roth   O'Cannavan    Male        Heitan
# 11    12         Rey       Meharg  Female   Wangqingtuo
# 19    20      Ettore     Gerriets    Male         Pedra
# 24    25       Shaun       Bridle  Female         Xitou
# 31    32   Westleigh  Belderfield    Male   Xiang Ngeun
# ..   ...         ...          ...     ...           ...
# 980  981  Claudianus      Harlowe    Male          Daet
# 986  987        Gris     Durrance    Male    Pittsburgh
# 990  991         Mic     Benbough    Male      Arbeláez
# 991  992      Scotti        Dusey    Male  Medveditskiy
# 992  993        Levi      Ramsell    Male   Lluchubamba
#
#                    Job Title     Salary   Latitude   Longitude  clean_salary  \
# 8      VP Product Management  $73697.10  32.027934  106.657113      73697.10
# 11   Systems Administrator I  $73423.70  39.172378  116.931607      73423.70
# ...

# %%
df.sort_values('clean_salary')
# Out:
#       id first_name    last_name  gender              City  \
# 619  620      Hamil   Eyckelbeck    Male            Gaoshi
# 581  582     Ramsay        Milam    Male            Jarash
# 832  833     Damara      Beaford  Female           Połomia
# 337  338      Linus       Estcot    Male          Paris 13
# 810  811      Leyla       Huelin  Female        Santa Rita
# ..   ...        ...          ...     ...               ...
# 899  900   Bancroft  Donisthorpe    Male       Karangtawar
# 36    37      Nicko        Frays    Male            Caxias
# 84    85    Gothart       Olivey    Male        Zhongcheng
# 812  813   Harmonia         Carn  Female  Bangbayang Kaler
# 874  875       Rivy        Adney  Female         Mesopotam
#
#                     Job Title     Salary   Latitude   Longitude  clean_salary  \
# 619  Database Administrator I  $10101.92  29.184943  105.055945      10101.92
# 581     VP Product Management  $10210.85  32.274652   35.896076      10210.85
# ...

# %%
df.sort_values('clean_salary', ascending = False)
# Out:
#       id first_name    last_name  gender              City  \
# 874  875       Rivy        Adney  Female         Mesopotam
# 812  813   Harmonia         Carn  Female  Bangbayang Kaler
# 84    85    Gothart       Olivey    Male        Zhongcheng
# 36    37      Nicko        Frays    Male            Caxias
# 899  900   Bancroft  Donisthorpe    Male       Karangtawar
# ..   ...        ...          ...     ...               ...
# 810  811      Leyla       Huelin  Female        Santa Rita
# 337  338      Linus       Estcot    Male          Paris 13
# 832  833     Damara      Beaford  Female           Połomia
# 581  582     Ramsay        Milam    Male            Jarash
# 619  620      Hamil   Eyckelbeck    Male            Gaoshi
#
#                     Job Title     Salary   Latitude   Longitude  clean_salary  \
# 874  Environmental Specialist  $99948.28  39.912087   20.097078      99948.28
# 812             Accountant IV  $99944.05  -6.751597  107.928790      99944.05
# ...

# %%
df['rank'] = df['clean_salary'].rank()
df
# Out:
#        id  first_name   last_name  gender           City  \
# 0       1     Melinde   Shilburne  Female      Nowa Ruda
# 1       2    Kimberly  Von Welden  Female         Bulgan
# 2       3      Alvera    Di Boldi  Female         London
# 3       4     Shannon   O'Griffin    Male  Divnomorskoye
# 4       5    Sherwood     Macieja    Male      Mytishchi
# ..    ...         ...         ...     ...            ...
# 995   996      Kathye     Grasser  Female       Dzaoudzi
# 996   997     Haskell    Kempston    Male  Ban Talat Nua
# 997   998  Holly-anne       Gerbl  Female        Guanaja
# 998   999      Marysa      Purdie  Female          Sioah
# 999  1000      Jewell    Haselden  Female    Springfield
#
#                                 Job Title     Salary   Latitude   Longitude  \
# 0                     Assistant Professor  $57438.18  50.577407   16.496718
# 1                           Programmer II  $62846.60  48.823157  103.521820
# ...

# %%
df['rank'] = df.rank(ascending= False)
df.head()
# Out:
#    id first_name   last_name  gender           City  \
# 0   1    Melinde   Shilburne  Female      Nowa Ruda
# 1   2   Kimberly  Von Welden  Female         Bulgan
# 2   3     Alvera    Di Boldi  Female         London
# 3   4    Shannon   O'Griffin    Male  Divnomorskoye
# 4   5   Sherwood     Macieja    Male      Mytishchi
#
#                       Job Title     Salary   Latitude   Longitude  \
# 0           Assistant Professor  $57438.18  50.577407   16.496718
# 1                 Programmer II  $62846.60  48.823157  103.521820
# 2                           NaN  $57576.52  39.994746  116.339773
# 3  Budget/Accounting Analyst II  $61489.23  44.504721   38.130017
# 4                      VP Sales  $63863.09        NaN   37.648995
#
#    clean_salary  female_salary   male_salary    rank
# 0      57438.18   57438.180000  55361.093839  1000.0
# 1      62846.60   62846.600000  55361.093839   999.0
# 2      57576.52   57576.520000  55361.093839   998.0
# ...

# %%
df['rank'] = df['clean_salary'].rank(ascending=False)
df.sort_values('rank')
# Out:
#       id first_name    last_name  gender              City  \
# 874  875       Rivy        Adney  Female         Mesopotam
# 812  813   Harmonia         Carn  Female  Bangbayang Kaler
# 84    85    Gothart       Olivey    Male        Zhongcheng
# 36    37      Nicko        Frays    Male            Caxias
# 899  900   Bancroft  Donisthorpe    Male       Karangtawar
# ..   ...        ...          ...     ...               ...
# 810  811      Leyla       Huelin  Female        Santa Rita
# 337  338      Linus       Estcot    Male          Paris 13
# 832  833     Damara      Beaford  Female           Połomia
# 581  582     Ramsay        Milam    Male            Jarash
# 619  620      Hamil   Eyckelbeck    Male            Gaoshi
#
#                     Job Title     Salary   Latitude   Longitude  clean_salary  \
# 874  Environmental Specialist  $99948.28  39.912087   20.097078      99948.28
# 812             Accountant IV  $99944.05  -6.751597  107.928790      99944.05
# ...

# %%
import pandas as pd
data = ['A','B','C','D']
pd.DataFrame(data,index=['1','2','3','4','5'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# c:\program files\python37\lib\site-packages\pandas\core\internals\managers.py in create_block_manager_from_blocks(blocks, axes)
#    1673
# -> 1674         mgr = BlockManager(blocks, axes)
#    1675         mgr._consolidate_inplace()
#
# c:\program files\python37\lib\site-packages\pandas\core\internals\managers.py in __init__(self, blocks, axes, do_integrity_check)
#     148         if do_integrity_check:
# --> 149             self._verify_integrity()
#     150
#
# c:\program files\python37\lib\site-packages\pandas\core\internals\managers.py in _verify_integrity(self)
#     328             if block.shape[1:] != mgr_shape[1:]:
# --> 329                 raise construction_error(tot_items, block.shape[1:], self.axes)
#     330         if len(self.items) != tot_items:
#
# ...

# %%
byzo = 'hello world!'
c = 0
for x in byzo:
    z = x + "!"
    print(z)
    c = c + 1
# Out:
# h!
# e!
# l!
# l!
# o!
#  !
# w!
# o!
# r!
# l!
# d!
# !!

# %%
scores = "67 80 90 78 93 20 79 89 96 97 92 88 79 68 58 90 98 100 79 74 83 88 80 86 85 70 90 100"
a_scores = 0
for score in scores:
    if int(score) > 90 or int(score) == 90:
        a_scores += 1
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-65-e3b9a27d5520> in <module>
#       2 a_scores = 0
#       3 for score in scores:
# ----> 4     if int(score) > 90 or int(score) == 90:
#       5         a_scores += 1
#
# ValueError: invalid literal for int() with base 10: ' '

# %%
scores = "67 80 90 78 93 20 79 89 96 97 92 88 79 68 58 90 98 100 79 74 83 88 80 86 85 70 90 100"
scores_split = scores.split(" ")
a_scores = 0
for x in scores_split:
    x = float(x)
    if x >= 90:
        a_scores += 1

# %%
a_scores
# Out:
# 10

# %%
stopwords = ['to', 'a', 'for', 'by', 'an', 'am', 'the', 'so', 'it', 'and', "The"]
org = "The organization for health, safety, and education"

stopwords = ['to', 'a', 'for', 'by', 'an', 'am', 'the', 'so', 'it', 'and', 'The']
sent = "The water earth and air are vital"

acro = '. '.join(word[:2].upper() for word in sent.split() if word not in stopwords)
